# %% [markdown]
# # PyTorch Homework
# ## 作業說明
# 這個作業希望以 PyTorch 的框架透過實作讓同學了解基本的讀取資料集、搭建模型以及訓練的過程。
#
# 這次作業分成三大部份及若干小部份，有一些**被註解框起來的區域**以及 **?** 的部份需要完成。
#
# 1. **資料準備 - 30%**
#     + Transformation
#     + Custom dataset definition - 10%
#     + Create datasets - 10%
#     + Create dataloaders - 10%
#
#
# 2. **建立模型 - 35%**
#     + flatten function - 5%
#     + 使用 nn.Module 建立模型 - 10%
#     + 使用 nn.Sequential 建立模型 - 10%
#     + 自己設計模型 - 10%
#
#
# 3. **訓練模型 - 35%**
#     + Loss function & optimizer - 5%
#     + 訓練 - 20%
#         + 完成程式碼 - 10%
#         + 自行設計的模型測試集準確率(只看最後 5 個 epoch 中的 best accuracy) - 10%
#             + 達到 50% baseline - 5%
#             + Bonus: 準確率超過 baseline 越多拿越高 - 5%
#     + 儲存模型 - 5%
#     + 繪製 loss 及 accuracy 圖表 - 5%
#
# ## 作業繳交
# 1. 繳交期限：
#
#
# 2. 繳交方式：
#
#     只需繳交這份完成的 ipynb 檔至 moodle，每個 cell 的執行結果都要顯示出來(訓練過程、loss curves 等等)，會用這些結果評分，不需要上傳訓練好的模型。
#
#     檔案命名格式：學號_姓名_hw2.ipynb (ex: F12345678_王大明_hw2.ipynb)
#     * **格式不對的話會扣 10 分！！！**
#
#
# 3. 有問題請寄信至助教信箱 ne6094041@gs.ncku.edu.tw 或於 TA hour 至資訊新館65601室找助教詢問。
#     + TA hour: 星期一和四 14:00 ~ 16:30

# %% [markdown]
# ## Import

# %%
import os
import os.path as osp

from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
# !pip install torchviz
from torchviz import make_dot
from google.colab import drive
drive.mount('/content/drive')
# %matplotlib inline
# Out:
# Collecting torchviz
#   Downloading torchviz-0.0.2.tar.gz (4.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchviz) (1.10.0+cu111)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (from torchviz) (0.10.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchviz) (3.10.0.2)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4151 sha256=492e92583898faef5b7dbe373f10ee77686b3c8c1e5ca73104bcf3c11e5bebb0
#   Stored in directory: /root/.cache/pip/wheels/04/38/f5/dc4f85c3909051823df49901e72015d2d750bd26b086480ec2
# Successfully built torchviz
# Installing collected packages: torchviz
# Successfully installed torchviz-0.0.2
# Mounted at /content/drive

# %% [markdown]
# ## Hyperparamters
# 可以自行新增或調整需要的 hyperparameter

# %%
SEED = 42

# data
DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/stanford_dog'
BATCH_SIZE = 32 # default = 32
NUM_WORKERS = 4 # default = 4
MEAN, STD = (0.485, 0.456, 0.406), (0.229, 0.224, 0.225) # mean and std for ImageNet

# training
LR = 1e-3
EPOCHS = 75
USE_CUDA = True # use cuda or not
MOMENTUM = 0.9
WEIGHT_DECAY = 1e-4
PRINT_FREQ = 10

# %% [markdown]
# ## GPU Setting
# 用 ```torch.cuda.is_available()``` 測試系統是否能使用 cuda

# %%
device = 'cpu'
if USE_CUDA and torch.cuda.is_available(): # 若想使用 cuda 且可以使用 cuda
    device = 'cuda'
print(f'Using {device} for training.')
# Out:
# Using cuda for training.

# %% [markdown]
# ## 1. Preparing Dataset
# PyTorch 中處理資料的部份主要由兩種 API 組成:
# + ```Dataset```: 定義如何讀取資料，並對資料做前處理(搭配 ```transforms```)
# + ```DataLoader```: 負責將多個樣本打包成 mini-batch 、處理資料取樣、以 multi-threading 或 multi-processing 的方式讀取資料等等

# %% [markdown]
# ### 1.1 Transformations
# Pytorch 的 ```transforms``` API 包含許多常用的方法，如縮放、剪裁、翻轉、旋轉、自定義 transform 等等，也包含不同影像格式之間與 tensor 的型態轉換。
#
# 每個 transform 方法可以單獨地被套用在影像上，也可以使用 ```Compose()``` 將許多方法組合在一起，並且會自動地照組合順序套用在影像上
#
# 這裡的 transformations 是常見且基本的組合，雖然這裡不需要填寫，但你可以在裡面增加一些 augmentation 幫助後面的模型訓練。

# %%
normalize = transforms.Normalize(mean=MEAN, std=STD)

# a set of common trasnformation combination for training
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    normalize
])

# transformations for testing do not need to do fancy tricks
test_transforms = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    normalize
])

# %% [markdown]
# ### 1.2 定義 dataset
# 自定義的資料集會繼承 ```Dataset```，並且 overwrite 以下 3 個 function:
# 1. ```__init__```: 建立資料集中樣本的讀取路徑以及 label 清單
# 2. ```__len__```: 回傳資料集大小，即樣本的數量
# 3. ```__getitem__```: 實際讀取資料的 function ，根據給定的 index 讀取影像，並對影像進行 transformation ，最後回傳處理過的影像以及其 label 。
#
# 在這裡，我們會將每張影像的讀取路徑儲存在 ```samples``` 裡，其對應的 label 儲存在 ```labels```中。
#
# 請完成以下 ? 處以及被註解框起來的區域。

# %%
class DogDataset(Dataset):
    def __init__(self, samples, classes, cls_to_idx, transform=None):
        """
        samples: 儲存每張影像的路徑以及 label 的清單
        classes: 所有類別名稱的清單
        cls_to_idx: 類別和對應 index 的 dict
        transform: 要對影像執行的 transformation
        """
        self.transform = transform
        
        self.classes = classes
        self.cls_to_idx = cls_to_idx
        self.targets = [s[1] for s in samples] # list of labels corresponding to samples
        self.samples = [s[0] for s in samples] # list of sample paths
    
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        
        ###############################################################################
        # TODO : get the image path and label of the given index from the lists       #
        # Hints:                                                                      #
        # path = ???                                                                  #
        # label = ???                                                                 #
        ###############################################################################
        path = self.samples[idx]
        label = self.targets[idx]
        ###############################################################################
        #                            END TO DO                                        #
        ###############################################################################

        # load the image using PIL.Image.open()
        img = Image.open(path)
        
        ###############################################################################
        # TODO : apply the transformation on the loaded image                         #
        # Hints:                                                                      #
        # img = ???                                                                   #
        ###############################################################################
        img = self.transform(img)
        ###############################################################################
        #                            END TODO                                         #
        ###############################################################################
        
        
        return img, label

# %% [markdown]
# ### 1.3 Create datasets
# 首先找出所有資料的路徑並儲存成清單
#
# 這裡不用填寫，但需要執行。

# %%
def find_files(folder):
    """
    Getting the list of files and their labels.
    
    Returns:
    classes: list of class names
    cls_to_idx: dict that map class names to their interger labels
    instances: dict that uses labels as keys and the corresponding tuples (samples, # of samples) as values
    """
    # find classes under the folder
    folder_path = os.path.expanduser(folder)
    classes = []
    for name in os.listdir(folder_path):
        dir_path = os.path.join(folder,name)
        if os.path.isdir(dir_path): # remove '.DS_Store'
            classes.append(name)
    #classes = os.listdir(folder_path) # class list
    cls_to_idx = {name: i for i, name in enumerate(classes)} # {class name: index}
        
    # find files and make list of them
    instances = {}
    for cls in sorted(cls_to_idx.keys()):
        cls_idx = cls_to_idx[cls]
        cls_path = osp.join(folder_path, cls) # path to the class folder
        files = os.listdir(cls_path) # list of images under the class
        items = [(osp.join(cls_path, name), cls_idx) for name in files] # combine them to form complete paths
        instances[cls_idx] = (items, len(items)) # (list of samples of the class, num of images in this class)
        
    return classes, cls_to_idx, instances

# get the list of samples under the folder
classes, cls_to_idx, instances = find_files(DATA_PATH)
print(f'There are {len(classes)} classes and {sum([s[1] for s in instances.values()])} images.')
# Out:
# There are 20 classes and 3633 images.

# %% [markdown]
# #### Split dataset
# 若資料集本身沒有區分訓練集、驗證集或測試集，我們就必須手動分割出這些子集。
#
# 這次作業採用「訓練集:測試集 = 8:2」的分割策略，對每個類別中的樣本都採用這個比例，這裡使用 ```sklearn``` 的 ```train_test_split``` 。
#
# 請完成以下 ? 處以及被註解框起來的區域。

# %%
train_samples = []
test_samples = []

# iterate through all classes, split the samples and store them in the lists
for cls_idx, cls_samples in instances.items():
    train, test = train_test_split(cls_samples[0], test_size=0.2, random_state=SEED)  # split
    train_samples += train
    test_samples += test
#     print(train)

###############################################################################
# TODO : use the sample lists to construct train dataset and test dataset     #
# Hints:                                                                      #
# train_dataset = DogDataset(?, ?, ?, ?)                                      #
# test_dataset = DogDataset(?, ?, ?, ?)                                       #
###############################################################################
train_dataset = DogDataset(samples=train_samples,classes=classes,cls_to_idx=cls_to_idx,transform=train_transforms)
test_dataset  = DogDataset(samples=test_samples,classes=classes,cls_to_idx=cls_to_idx,transform=test_transforms)
###############################################################################
#                            END TODO                                         #
###############################################################################

print('Size of train dataset: %d, size of test dataset: %d' % (len(train_dataset), len(test_dataset)))
# Out:
# Size of train dataset: 2898, size of test dataset: 735

# %% [markdown]
# ### 1.4 Create dataloaders
# ```DataLoader``` 負責將從 dataset 中得到的東西根據採樣策略 (```sampler```)、batch size 大小 (```batch_size```)、是否打亂資料順序 (```shuffle```)（訓練時通常會打亂），將樣本打包成一個 mini-batch ，並根據 ```num_workers``` 調整讀取資料的所需的資源。
#
# 從 dataloader 中讀取資料的方式為像 python generator 或 list 一樣使用迴圈取出資料，可以在後面的訓練階段中看到。
#
# 請完成以下被註解框起來的區域。

# %%
train_loader = None
test_loader = None
###############################################################################
# TODO : create dataloaders for train dataset and test dataset                #
# Hints:                                                                      #
# train_loader = DataLoader(?, ?, ?, ?)                                       #
# test_loader = DogDataset(?, ?, ?, ?)                                        #
###############################################################################
train_loader = DataLoader(dataset=train_dataset,batch_size=BATCH_SIZE,shuffle=True,num_workers=NUM_WORKERS)
test_loader  = DataLoader(dataset=test_dataset,batch_size=BATCH_SIZE,shuffle=True,num_workers=NUM_WORKERS)
###############################################################################
#                            END TODO                                         #
###############################################################################

print(f'There are {len(train_loader)} training batches and {len(test_loader)} testing batches')
# Out:
# There are 91 training batches and 23 testing batches
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ## 2. Model
# PyTorch 的模型（包括基本的 conv, batchnorm 層等等）大部分都是繼承 ```nn.Module```，並且都具備
# + ```__init__```: 定義內部結構，例如 conv, pool 等等。
# + ```forward```: 定義前面的結構操作如何串聯，也就是這些結構的順序，是輸入的張量真正進行計算的 function 。
#
# 用來建立模型的 API 有很多種，包括 ```nn.Module```、```nn.Sequential```、```nn.ModuleList```、```nn.ModuleDict``` 等等。
#
# 這次作業要求以前兩種方法建立模型，分成 2.1 以及 2.2，並在這兩個部分裡完成下面所敘述的模型結構：
# 1. A convolution layer with 64 11*11 filters, stride 4 and padding 2
# 2. ReLU
# 3. A Maxpooling layer with 3*3 kernel and stride 2
# 4. A convolution layer with 128 5*5 filters and padding 2
# 5. ReLU
# 6. A Maxpooling layer with 3*3 kernel and stride 2
# 7. A convolution layer with 256 3*3 filters and padding 1
# 8. ReLU
# 9. A convolution layer with 128 3*3 filters and padding 1
# 10. ReLU
# 11. A convolution layer with 128 3*3 filters and padding 1
# 12. ReLU
# 13. A Maxpooling layer with 3*3 kernel and stride 2
# 14. flatten
# 15. A fully-connected layer that outputs tensor to 1024
# 16. ReLU
# 17. A fully-connected layer that outputs tensor to 256
# 18. ReLU
# 19. A fully-connected layer that outputs tensor to 20

# %% [markdown]
# ### 2.1 flatten function
# Flatten 作用是將 tensor 除了 batch 以外的其他維度全部攤平。
#
# 請完成以下被註解框起來的區域。

# %%
def flatten(x):
    ###############################################################################
    # TODO : flatten the input tensor x with shape (B, C, H, W) to (B, C*H*W)     #
    ###############################################################################    
    size = x.size()[1:]
    num_features = 1
    for s in size:
        num_features *= s
        
    x = x.view(-1,num_features)
    ###############################################################################
    #                            END TODO                                         #
    ###############################################################################
    return x

# %% [markdown]
# ### 2.2 使用 nn.Module 建立模型
# 如同一般定義 python class 的方法，在建構子中定義會用到的 layer ，並在 forward 中定義其之間的操作連結。
#
# 請完成以下被註解框起來的區域。

# %%
class TestModel(nn.Module):
    def __init__(self):
        super(TestModel, self).__init__() # this line must be done first
        ###############################################################################
        # TODO : Define the model described above by specifying the required layers   #
        # Hints:                                                                      #
        # self.conv1 = ?                                                              #
        # self.relu = ?                                                               #
        # self.maxpool1 = ?                                                           #
        # self.conv2 = ?                                                              #
        # ...                                                                         #
        ###############################################################################
        self.conv1 = nn.Conv2d(3,64,11,stride=4,padding=2)
        self.relu1 = nn.ReLU()
        
        self.maxpool1 = nn.MaxPool2d(3,stride=2)
        
        self.conv2 = nn.Conv2d(64,128,5,padding=2)
        self.relu2 = nn.ReLU()
        
        self.maxpool2 = nn.MaxPool2d(3,stride=2)
        
        self.conv3 = nn.Conv2d(128,256,3,padding=1)
        self.relu3 = nn.ReLU()
        
        self.conv4 = nn.Conv2d(256,128,3,padding=1)
        self.relu4 = nn.ReLU()
        
        self.conv5 = nn.Conv2d(128,128,3,padding=1)
        self.relu5 = nn.ReLU()
        
        self.maxpool3 = nn.MaxPool2d(3,stride=2)
        
        #self.flatten = flatten()
        self.fc1 = nn.Linear(128*6*6,1024)
        self.relu6 = nn.ReLU()
        self.fc2 = nn.Linear(1024,256)
        self.relu7 = nn.ReLU()
        self.fc3 = nn.Linear(256,20)
        
        ###############################################################################
        #                            END TO DO                                         #
        ###############################################################################
        
    
    def forward(self, x):
        ###############################################################################
        # TODO : Implement the forward function, you should use the layers            #
        #        defined in __init__ function and connect them                        #
        # Hints:                                                                      #
        # x = self.?(?)                                                               #
        # x = self.?(?)                                                               #
        # ...                                                                         #
        ###############################################################################
        
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.maxpool1(x)
        
        x = self.conv2(x)
        x = self.relu2(x)
        x = self.maxpool2(x)
        
        x = self.conv3(x)
        x = self.relu3(x)
        
        x = self.conv4(x)
        x = self.relu4(x)
        
        x = self.conv5(x)
        x = self.relu5(x)
        x = self.maxpool3(x)
        
        x = flatten(x)
        
        x = self.fc1(x)
        x = self.relu6(x)
        x = self.fc2(x)
        x = self.relu7(x)
        x = self.fc3(x)
        
        ###############################################################################
        #                            END TODO                                         #
        ###############################################################################
        
        return x

x = torch.randn(4, 3, 224, 224)
model = TestModel()
make_dot(model(x), params=dict(model.named_parameters()))

# 可以將畫出來的圖與助教提供的圖對比看看是否一樣或十分相似

# %% [markdown]
# ### 2.3 使用 nn.Sequential 建立模型
# ```nn.Sequential``` 的不同之處在於可以直接從一系列的 layer 建立模型，不需定義 ```__init__``` 也不用定義 ```forward``` ，會自動依序用每一層進行 forward ，相對地，其成員皆需有 ```forward``` 可以呼叫。
#
# 請完成以下被註解框起來的區域。

# %%
# wrap the flatten function
class Flatten(nn.Module):
    def forward(self, x):
        return flatten(x)

model = None
###############################################################################
# TODO : Define the model described above using nn.Sequential                 #
# Hints:                                                                      #
# model = nn.Sequential(...)                                                  #
###############################################################################
model = nn.Sequential(
            nn.Conv2d(3,64,11,stride=4,padding=2), 
            nn.ReLU(),
            nn.MaxPool2d(3,stride=2),           
            nn.Conv2d(64,128,5,padding=2),       
            nn.ReLU(),
            nn.MaxPool2d(3,stride=2),             
            nn.Conv2d(128,256,3,padding=1),       
            nn.ReLU(),
            nn.Conv2d(256,128,3,padding=1),        
            nn.ReLU(),
            nn.Conv2d(128,128,3,padding=1),        
            nn.ReLU(),
            nn.MaxPool2d(3,stride=2),              
        
            nn.Flatten(),
            nn.Linear(128*6*6,1024),
            nn.ReLU(),
            nn.Linear(1024,256),
            nn.ReLU(),
            nn.Linear(256,20)
        )
###############################################################################
#                            END TODO                                         #
###############################################################################

x = torch.randn(4, 3, 224, 224)
make_dot(model(x), params=dict(model.named_parameters()))
# 可以將畫出來的圖與助教提供的圖對比看看是否一樣或十分相似

# %% [markdown]
# ### 2.4 自行設計模型
# 請使用上述任一種方式設計自己的模型(實體化後的模型名稱為 ```mymodel```)，並解釋自己的設計。最後的分類為 20 個類別。
#
# ## **不可以直接呼叫```torchvision.models```中已經寫好的模型，但可以照著論文中的模型架構手刻出來**
#
# ## **不可以使用預訓練過的模型權重作為初始狀態，也就是不能用預訓練的模型再 fine-tune**
#
# 請完成以下被註解框起來的區域。

# %%
mymodel = None
###############################################################################
# TODO : Design your own model and instantiate as mymodel.                    #
# Hint:                                                                       #
# You can start from modifying the model above.                               #
###############################################################################

# VGG-16
model = nn.Sequential(
            # block1
            nn.Conv2d(3,64,3,stride=1,padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64,64,3,stride=1,padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2,stride=2),
            # block2
            nn.Conv2d(64,128,3,stride=1,padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128,128,3,stride=1,padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2,stride=2),
            # block3
            nn.Conv2d(128,256,3,stride=1,padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256,256,3,stride=1,padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256,256,3,stride=1,padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2,stride=2),
            # block4
            nn.Conv2d(256,512,3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512,512,3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512,512,3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2,stride=2),
            # block5
            nn.Conv2d(512,512,3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512,512,3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512,512,3,stride=1,padding=1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2,stride=2),
            nn.AvgPool2d(1,stride=1),
            
            nn.Flatten(),
            
            nn.Linear(512*7*7,4096),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4096,4096),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(4096,20),
            nn.LogSoftmax(dim=1)
)

###############################################################################
#                            END TODO                                         #
###############################################################################
x = torch.randn(4, 3, 224, 224)
make_dot(model(x), params=dict(model.named_parameters()))

# %% [markdown]
# #### 模型解釋
#
# 我所採用的模型架構是以VGG-16為基礎，共有13層的卷積層和3層的全連接層，再加入額外的動作來提升準確率。
# * 在每一次的convolution之後，加入了batch normalization，來防止梯度消失或是梯度爆炸的問題，而在經由實際測試後，也發現加入了batch normalization的模型，能夠有效提升訓練的準確度。
# * 而在全連接層的部分，透過dropout來丟棄一半的隱藏神經元，以減少神經元之間的依賴性，進而減少overfitting的情況。
# * 而在最後我使用logSigmoid函數來做分類問題。

# %% [markdown]
# ## 3 訓練模型

# %% [markdown]
# ### 3.1 設定 loss function 以及 optimizer
# + 對於分類問題，通常使用 cross entropy 就足夠
# + Optimizer 常用的有 SGD, Adam 等等
#
# 請完成以下 ? 處以及被註解框起來的區域。

# %%
criterion = None
optimizer = None
###############################################################################
# TODO : Setting up loss function (criterion) and optimizer                   #
###############################################################################
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr=LR,momentum=MOMENTUM)

###############################################################################
#                            END TODO                                         #
###############################################################################

# %%
# 這個 cell 不用填

# helper functions
def accuracy(outputs, targets):
    """Compute accuracy"""
    batch_size = targets.size(0)

    pred = outputs.argmax(1)
    correct = pred.eq(targets)
    acc = correct.float().sum(0) / batch_size

    return acc

class AverageMeter(object):
    """A Meter that records numbers and compute the average."""
    def __init__(self):
        self.reset()
    
    def reset(self):
        self.val = 0.0
        self.avg = 0.0
        self.sum = 0.0
        self.count = 0.0
    
    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# ### 3.2 開始訓練
# 流程：
#
# 訓練階段，在一個 iteration 中，
# 1. 取出 batch 中的資料
# 2. 由模型預測分類結果 (forward)
# 3. 計算 loss
# 4. 清空梯度
# 5. backward 計算梯度
# 6. 更新模型參數
#
# 重複以上動作直到所有 batch 迭代完成後，進入測試階段，使用測試集測試模型表現，計算準確度。
#
# 到這裡是一個 epoch 的動作，重複直到設定的 epoch 數量後結束。
#
# 以下會把每一個 epoch 的訓練和測試部份寫成兩個 function，請完成 ? 的部分。

# %%
def train(epoch, model, loader, criterion, optimizer):
    """This function trains for 1 epoch and returns the epoch loss and accuracy."""
    # recorders
    loss_m = AverageMeter()
    acc_m = AverageMeter()
    
    model.train() # Set model to training mode
    
    for idx, (imgs, labels) in enumerate(loader): # load data
        # put the data to correct device
        imgs, labels = imgs.to(device), labels.to(device)

        # model forward
        outputs = model(imgs)

        # calculate loss
        loss = criterion(outputs, labels)

        # clear optimizer gradients
        optimizer.zero_grad()

        # backward to calculate gradients
        loss.backward()

        # update model parameters
        optimizer.step()
        
        # accuracy (?)
        acc = accuracy(outputs, labels)
        
        # record loss and acc
        loss_m.update(loss.item(), imgs.size(0))
        acc_m.update(acc.item(), imgs.size(0))
        
        # logging
        if (idx >= 0) and (idx % PRINT_FREQ == 0):
            print("[{:3d}/{}] Train Loss {:.3f} Acc {:.3f}".format(
                idx, len(loader), loss_m.val, acc_m.val
            ))
        
    return loss_m.avg, acc_m.avg

# %%
def test(model, loader, criterion):
    """This function tests the model on the test set."""
    # recorders
    loss_m = AverageMeter()
    out_list, y_list = [], []
    
    model.eval() # set model to eval mode
    
    with torch.no_grad(): # no need to compute gradient when testing
        for imgs, labels in loader:
            imgs, labels = imgs.to(device), labels.to(device)
            
            # model forward
            outputs = model(imgs)
            
            # compute loss
            loss = criterion(outputs, labels)
            
            y_list.append(labels)
            out_list.append(outputs)
            loss_m.update(loss.item())
        
        # concat all predictions and answers to compute accuracy
        pred = torch.cat(out_list)
        y = torch.cat(y_list)
        acc = accuracy(pred, y)
    
    return loss_m.avg, acc.item()

# %% [markdown]
# #### Let's GOOOOOO
#
# 請完成以下 ? 處，並執行這個 cell 以開始訓練。

# %%
# move model to GPU if available
if device == 'cuda':
    model.cuda()

# for recording
train_loss, test_loss = [], []
train_acc, test_acc = [], []
best_acc = (0, 0.0) # (epoch, acc)

for epoch in range(EPOCHS):
    print("---------------- Epoch {} ----------------".format(epoch+1))
    
    model.to(device)
    
    # training
    loss, acc = train(EPOCHS, model, train_loader, criterion, optimizer)
    # saving epoch loss and acc for plotting
    train_loss.append(loss)
    train_acc.append(acc)
    # logging
    print('Epoch {:3d}/{} Train Loss {:.3f} Acc {:.3f}'.format(epoch+1, EPOCHS, loss, acc))
    
    # testing
    print("---------------- Testing ----------------")
    loss, acc = test(model, test_loader, criterion)
    test_loss.append(loss)
    test_acc.append(acc)        
    # logging
    print('Epoch {:3d}/{} Test Loss {:.3f} Acc {:.3f}'.format(epoch+1, EPOCHS, loss, acc))
    
    if acc > best_acc[1]:
        best_acc = (epoch+1, acc)

print('--' * 10)
print('The Best accuracy is {:.3f} at epoch {}'.format(best_acc[1], best_acc[0]))
# Out:
# ---------------- Epoch 1 ----------------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [  0/91] Train Loss 3.009 Acc 0.062
# [ 10/91] Train Loss 2.972 Acc 0.062
# [ 20/91] Train Loss 3.126 Acc 0.062
# [ 30/91] Train Loss 3.016 Acc 0.000
# [ 40/91] Train Loss 2.984 Acc 0.094
# [ 50/91] Train Loss 3.113 Acc 0.000
# [ 60/91] Train Loss 2.884 Acc 0.219
# [ 70/91] Train Loss 3.041 Acc 0.031
# [ 80/91] Train Loss 2.898 Acc 0.125
# [ 90/91] Train Loss 2.888 Acc 0.111
# Epoch   1/75 Train Loss 2.974 Acc 0.082
# ---------------- Testing ----------------
# Epoch   1/75 Test Loss 2.741 Acc 0.173
# ---------------- Epoch 2 ----------------
# [  0/91] Train Loss 2.987 Acc 0.125
# [ 10/91] Train Loss 2.790 Acc 0.125
# [ 20/91] Train Loss 2.793 Acc 0.156
# [ 30/91] Train Loss 2.829 Acc 0.125
# [ 40/91] Train Loss 2.772 Acc 0.125
# [ 50/91] Train Loss 2.725 Acc 0.125
# [ 60/91] Train Loss 2.886 Acc 0.094
# [ 70/91] Train Loss 2.853 Acc 0.125
# [ 80/91] Train Loss 2.831 Acc 0.125
# [ 90/91] Train Loss 2.866 Acc 0.278
# Epoch   2/75 Train Loss 2.750 Acc 0.141
# ---------------- Testing ----------------
# Epoch   2/75 Test Loss 2.482 Acc 0.224
# ---------------- Epoch 3 ----------------
# [  0/91] Train Loss 2.902 Acc 0.062
# [ 10/91] Train Loss 2.526 Acc 0.219
# [ 20/91] Train Loss 2.463 Acc 0.250
# [ 30/91] Train Loss 2.614 Acc 0.250
# [ 40/91] Train Loss 2.599 Acc 0.188
# [ 50/91] Train Loss 2.214 Acc 0.344
# [ 60/91] Train Loss 2.572 Acc 0.188
# [ 70/91] Train Loss 2.675 Acc 0.188
# [ 80/91] Train Loss 2.626 Acc 0.219
# [ 90/91] Train Loss 2.480 Acc 0.222
# Epoch   3/75 Train Loss 2.598 Acc 0.188
# ---------------- Testing ----------------
# Epoch   3/75 Test Loss 2.426 Acc 0.239
# ---------------- Epoch 4 ----------------
# [  0/91] Train Loss 2.673 Acc 0.219
# [ 10/91] Train Loss 2.235 Acc 0.281
# [ 20/91] Train Loss 2.864 Acc 0.062
# [ 30/91] Train Loss 2.573 Acc 0.094
# [ 40/91] Train Loss 2.377 Acc 0.219
# [ 50/91] Train Loss 2.123 Acc 0.281
# [ 60/91] Train Loss 2.568 Acc 0.188
# [ 70/91] Train Loss 2.439 Acc 0.219
# [ 80/91] Train Loss 2.555 Acc 0.281
# [ 90/91] Train Loss 2.196 Acc 0.444
# Epoch   4/75 Train Loss 2.473 Acc 0.220
# ---------------- Testing ----------------
# Epoch   4/75 Test Loss 2.347 Acc 0.263
# ---------------- Epoch 5 ----------------
# [  0/91] Train Loss 2.254 Acc 0.312
# [ 10/91] Train Loss 2.187 Acc 0.188
# [ 20/91] Train Loss 2.833 Acc 0.188
# [ 30/91] Train Loss 2.151 Acc 0.406
# [ 40/91] Train Loss 2.764 Acc 0.188
# [ 50/91] Train Loss 2.349 Acc 0.375
# [ 60/91] Train Loss 2.465 Acc 0.188
# [ 70/91] Train Loss 2.296 Acc 0.312
# [ 80/91] Train Loss 2.711 Acc 0.125
# [ 90/91] Train Loss 1.982 Acc 0.333
# Epoch   5/75 Train Loss 2.436 Acc 0.225
# ---------------- Testing ----------------
# Epoch   5/75 Test Loss 2.163 Acc 0.318
# ---------------- Epoch 6 ----------------
# [  0/91] Train Loss 2.216 Acc 0.281
# [ 10/91] Train Loss 2.471 Acc 0.250
# [ 20/91] Train Loss 2.385 Acc 0.219
# [ 30/91] Train Loss 2.702 Acc 0.188
# [ 40/91] Train Loss 2.465 Acc 0.156
# [ 50/91] Train Loss 2.246 Acc 0.375
# [ 60/91] Train Loss 2.523 Acc 0.219
# [ 70/91] Train Loss 2.328 Acc 0.344
# [ 80/91] Train Loss 2.822 Acc 0.156
# [ 90/91] Train Loss 2.503 Acc 0.056
# Epoch   6/75 Train Loss 2.396 Acc 0.243
# ---------------- Testing ----------------
# Epoch   6/75 Test Loss 2.184 Acc 0.325
# ---------------- Epoch 7 ----------------
# [  0/91] Train Loss 2.256 Acc 0.281
# [ 10/91] Train Loss 2.371 Acc 0.250
# [ 20/91] Train Loss 2.491 Acc 0.250
# [ 30/91] Train Loss 2.828 Acc 0.156
# [ 40/91] Train Loss 2.562 Acc 0.156
# [ 50/91] Train Loss 2.308 Acc 0.281
# [ 60/91] Train Loss 2.361 Acc 0.312
# [ 70/91] Train Loss 2.079 Acc 0.250
# [ 80/91] Train Loss 2.253 Acc 0.312
# [ 90/91] Train Loss 2.550 Acc 0.111
# Epoch   7/75 Train Loss 2.364 Acc 0.249
# ---------------- Testing ----------------
# Epoch   7/75 Test Loss 2.127 Acc 0.322
# ---------------- Epoch 8 ----------------
# [  0/91] Train Loss 2.420 Acc 0.375
# [ 10/91] Train Loss 2.364 Acc 0.188
# [ 20/91] Train Loss 2.050 Acc 0.375
# [ 30/91] Train Loss 2.414 Acc 0.312
# [ 40/91] Train Loss 2.412 Acc 0.250
# [ 50/91] Train Loss 2.333 Acc 0.219
# [ 60/91] Train Loss 2.529 Acc 0.219
# [ 70/91] Train Loss 2.281 Acc 0.188
# [ 80/91] Train Loss 2.490 Acc 0.156
# [ 90/91] Train Loss 1.795 Acc 0.444
# Epoch   8/75 Train Loss 2.318 Acc 0.270
# ---------------- Testing ----------------
# Epoch   8/75 Test Loss 2.137 Acc 0.331
# ---------------- Epoch 9 ----------------
# [  0/91] Train Loss 2.498 Acc 0.219
# [ 10/91] Train Loss 2.399 Acc 0.219
# [ 20/91] Train Loss 2.049 Acc 0.281
# [ 30/91] Train Loss 2.406 Acc 0.250
# [ 40/91] Train Loss 2.500 Acc 0.250
# [ 50/91] Train Loss 2.099 Acc 0.219
# [ 60/91] Train Loss 2.471 Acc 0.188
# [ 70/91] Train Loss 2.171 Acc 0.469
# [ 80/91] Train Loss 2.356 Acc 0.250
# [ 90/91] Train Loss 2.348 Acc 0.222
# Epoch   9/75 Train Loss 2.275 Acc 0.284
# ---------------- Testing ----------------
# Epoch   9/75 Test Loss 2.053 Acc 0.333
# ---------------- Epoch 10 ----------------
# [  0/91] Train Loss 2.047 Acc 0.312
# [ 10/91] Train Loss 2.097 Acc 0.406
# [ 20/91] Train Loss 2.317 Acc 0.219
# [ 30/91] Train Loss 2.287 Acc 0.250
# [ 40/91] Train Loss 2.066 Acc 0.406
# [ 50/91] Train Loss 2.263 Acc 0.375
# [ 60/91] Train Loss 2.493 Acc 0.125
# [ 70/91] Train Loss 2.226 Acc 0.156
# [ 80/91] Train Loss 1.709 Acc 0.531
# [ 90/91] Train Loss 2.098 Acc 0.278
# Epoch  10/75 Train Loss 2.248 Acc 0.295
# ---------------- Testing ----------------
# Epoch  10/75 Test Loss 2.099 Acc 0.332
# ---------------- Epoch 11 ----------------
# [  0/91] Train Loss 2.160 Acc 0.344
# [ 10/91] Train Loss 2.228 Acc 0.281
# [ 20/91] Train Loss 2.458 Acc 0.281
# [ 30/91] Train Loss 2.317 Acc 0.219
# [ 40/91] Train Loss 2.390 Acc 0.250
# [ 50/91] Train Loss 1.882 Acc 0.344
# [ 60/91] Train Loss 2.126 Acc 0.375
# [ 70/91] Train Loss 2.524 Acc 0.188
# [ 80/91] Train Loss 2.248 Acc 0.281
# [ 90/91] Train Loss 2.222 Acc 0.222
# Epoch  11/75 Train Loss 2.206 Acc 0.301
# ---------------- Testing ----------------
# Epoch  11/75 Test Loss 2.076 Acc 0.343
# ---------------- Epoch 12 ----------------
# [  0/91] Train Loss 2.254 Acc 0.250
# [ 10/91] Train Loss 2.292 Acc 0.344
# [ 20/91] Train Loss 2.235 Acc 0.250
# [ 30/91] Train Loss 2.111 Acc 0.312
# [ 40/91] Train Loss 2.163 Acc 0.312
# [ 50/91] Train Loss 2.388 Acc 0.250
# [ 60/91] Train Loss 2.098 Acc 0.438
# [ 70/91] Train Loss 2.312 Acc 0.312
# [ 80/91] Train Loss 2.552 Acc 0.250
# [ 90/91] Train Loss 3.032 Acc 0.167
# Epoch  12/75 Train Loss 2.181 Acc 0.312
# ---------------- Testing ----------------
# Epoch  12/75 Test Loss 1.926 Acc 0.381
# ---------------- Epoch 13 ----------------
# [  0/91] Train Loss 1.808 Acc 0.312
# [ 10/91] Train Loss 2.381 Acc 0.438
# [ 20/91] Train Loss 1.799 Acc 0.375
# [ 30/91] Train Loss 2.390 Acc 0.281
# [ 40/91] Train Loss 2.318 Acc 0.281
# [ 50/91] Train Loss 2.222 Acc 0.344
# [ 60/91] Train Loss 1.940 Acc 0.375
# [ 70/91] Train Loss 2.022 Acc 0.406
# [ 80/91] Train Loss 2.458 Acc 0.188
# [ 90/91] Train Loss 1.845 Acc 0.389
# Epoch  13/75 Train Loss 2.150 Acc 0.315
# ---------------- Testing ----------------
# Epoch  13/75 Test Loss 1.875 Acc 0.433
# ---------------- Epoch 14 ----------------
# [  0/91] Train Loss 2.163 Acc 0.312
# [ 10/91] Train Loss 2.650 Acc 0.219
# [ 20/91] Train Loss 1.963 Acc 0.438
# [ 30/91] Train Loss 2.077 Acc 0.344
# [ 40/91] Train Loss 1.897 Acc 0.344
# [ 50/91] Train Loss 1.978 Acc 0.375
# [ 60/91] Train Loss 2.061 Acc 0.375
# [ 70/91] Train Loss 2.158 Acc 0.344
# [ 80/91] Train Loss 2.251 Acc 0.375
# [ 90/91] Train Loss 2.039 Acc 0.389
# Epoch  14/75 Train Loss 2.125 Acc 0.328
# ---------------- Testing ----------------
# Epoch  14/75 Test Loss 2.087 Acc 0.347
# ---------------- Epoch 15 ----------------
# [  0/91] Train Loss 2.385 Acc 0.219
# [ 10/91] Train Loss 2.218 Acc 0.312
# [ 20/91] Train Loss 2.239 Acc 0.219
# [ 30/91] Train Loss 2.033 Acc 0.438
# [ 40/91] Train Loss 2.185 Acc 0.344
# [ 50/91] Train Loss 2.050 Acc 0.312
# [ 60/91] Train Loss 2.014 Acc 0.375
# [ 70/91] Train Loss 2.075 Acc 0.312
# [ 80/91] Train Loss 2.332 Acc 0.406
# [ 90/91] Train Loss 1.799 Acc 0.444
# Epoch  15/75 Train Loss 2.060 Acc 0.339
# ---------------- Testing ----------------
# Epoch  15/75 Test Loss 1.821 Acc 0.433
# ---------------- Epoch 16 ----------------
# [  0/91] Train Loss 1.778 Acc 0.438
# [ 10/91] Train Loss 1.895 Acc 0.375
# [ 20/91] Train Loss 2.337 Acc 0.250
# [ 30/91] Train Loss 2.183 Acc 0.438
# [ 40/91] Train Loss 1.830 Acc 0.469
# [ 50/91] Train Loss 1.677 Acc 0.500
# [ 60/91] Train Loss 1.864 Acc 0.344
# [ 70/91] Train Loss 2.182 Acc 0.312
# [ 80/91] Train Loss 2.370 Acc 0.188
# [ 90/91] Train Loss 1.698 Acc 0.556
# Epoch  16/75 Train Loss 2.054 Acc 0.345
# ---------------- Testing ----------------
# Epoch  16/75 Test Loss 1.916 Acc 0.386
# ---------------- Epoch 17 ----------------
# [  0/91] Train Loss 2.090 Acc 0.344
# [ 10/91] Train Loss 1.762 Acc 0.406
# [ 20/91] Train Loss 1.915 Acc 0.469
# [ 30/91] Train Loss 2.416 Acc 0.250
# [ 40/91] Train Loss 1.841 Acc 0.438
# [ 50/91] Train Loss 1.873 Acc 0.375
# [ 60/91] Train Loss 2.111 Acc 0.438
# [ 70/91] Train Loss 1.933 Acc 0.406
# [ 80/91] Train Loss 1.859 Acc 0.500
# [ 90/91] Train Loss 2.070 Acc 0.278
# Epoch  17/75 Train Loss 2.029 Acc 0.357
# ---------------- Testing ----------------
# Epoch  17/75 Test Loss 1.970 Acc 0.390
# ---------------- Epoch 18 ----------------
# [  0/91] Train Loss 2.454 Acc 0.219
# [ 10/91] Train Loss 1.750 Acc 0.500
# [ 20/91] Train Loss 2.149 Acc 0.281
# [ 30/91] Train Loss 2.005 Acc 0.281
# [ 40/91] Train Loss 1.885 Acc 0.500
# [ 50/91] Train Loss 1.937 Acc 0.375
# [ 60/91] Train Loss 1.848 Acc 0.406
# [ 70/91] Train Loss 1.753 Acc 0.375
# [ 80/91] Train Loss 1.960 Acc 0.344
# [ 90/91] Train Loss 3.098 Acc 0.278
# Epoch  18/75 Train Loss 1.996 Acc 0.364
# ---------------- Testing ----------------
# Epoch  18/75 Test Loss 1.818 Acc 0.434
# ---------------- Epoch 19 ----------------
# [  0/91] Train Loss 1.896 Acc 0.469
# [ 10/91] Train Loss 1.988 Acc 0.469
# [ 20/91] Train Loss 1.918 Acc 0.344
# [ 30/91] Train Loss 2.025 Acc 0.406
# [ 40/91] Train Loss 2.299 Acc 0.281
# [ 50/91] Train Loss 2.057 Acc 0.312
# [ 60/91] Train Loss 1.836 Acc 0.438
# [ 70/91] Train Loss 2.061 Acc 0.312
# [ 80/91] Train Loss 1.826 Acc 0.438
# [ 90/91] Train Loss 1.745 Acc 0.333
# Epoch  19/75 Train Loss 1.994 Acc 0.364
# ---------------- Testing ----------------
# Epoch  19/75 Test Loss 1.755 Acc 0.449
# ---------------- Epoch 20 ----------------
# [  0/91] Train Loss 2.104 Acc 0.219
# [ 10/91] Train Loss 2.004 Acc 0.281
# [ 20/91] Train Loss 1.748 Acc 0.438
# [ 30/91] Train Loss 1.744 Acc 0.438
# [ 40/91] Train Loss 1.973 Acc 0.344
# [ 50/91] Train Loss 1.973 Acc 0.375
# [ 60/91] Train Loss 1.444 Acc 0.531
# [ 70/91] Train Loss 1.668 Acc 0.469
# [ 80/91] Train Loss 2.291 Acc 0.250
# [ 90/91] Train Loss 1.755 Acc 0.389
# Epoch  20/75 Train Loss 1.914 Acc 0.381
# ---------------- Testing ----------------
# Epoch  20/75 Test Loss 1.782 Acc 0.426
# ---------------- Epoch 21 ----------------
# [  0/91] Train Loss 2.012 Acc 0.406
# [ 10/91] Train Loss 1.928 Acc 0.375
# [ 20/91] Train Loss 1.846 Acc 0.375
# [ 30/91] Train Loss 1.892 Acc 0.344
# [ 40/91] Train Loss 1.991 Acc 0.438
# [ 50/91] Train Loss 2.409 Acc 0.344
# [ 60/91] Train Loss 1.597 Acc 0.562
# [ 70/91] Train Loss 2.175 Acc 0.344
# [ 80/91] Train Loss 2.050 Acc 0.406
# [ 90/91] Train Loss 1.689 Acc 0.389
# Epoch  21/75 Train Loss 1.933 Acc 0.381
# ---------------- Testing ----------------
# Epoch  21/75 Test Loss 1.950 Acc 0.405
# ---------------- Epoch 22 ----------------
# [  0/91] Train Loss 1.865 Acc 0.438
# [ 10/91] Train Loss 1.725 Acc 0.406
# [ 20/91] Train Loss 1.896 Acc 0.375
# [ 30/91] Train Loss 1.857 Acc 0.312
# [ 40/91] Train Loss 2.167 Acc 0.312
# [ 50/91] Train Loss 1.683 Acc 0.438
# [ 60/91] Train Loss 1.838 Acc 0.438
# [ 70/91] Train Loss 2.045 Acc 0.344
# [ 80/91] Train Loss 2.105 Acc 0.375
# [ 90/91] Train Loss 2.051 Acc 0.389
# Epoch  22/75 Train Loss 1.887 Acc 0.404
# ---------------- Testing ----------------
# Epoch  22/75 Test Loss 1.724 Acc 0.446
# ---------------- Epoch 23 ----------------
# [  0/91] Train Loss 1.695 Acc 0.500
# [ 10/91] Train Loss 1.142 Acc 0.781
# [ 20/91] Train Loss 1.858 Acc 0.406
# [ 30/91] Train Loss 1.849 Acc 0.406
# [ 40/91] Train Loss 1.953 Acc 0.312
# [ 50/91] Train Loss 1.560 Acc 0.500
# [ 60/91] Train Loss 1.819 Acc 0.438
# [ 70/91] Train Loss 1.797 Acc 0.312
# [ 80/91] Train Loss 1.841 Acc 0.344
# [ 90/91] Train Loss 1.971 Acc 0.333
# Epoch  23/75 Train Loss 1.869 Acc 0.385
# ---------------- Testing ----------------
# Epoch  23/75 Test Loss 1.649 Acc 0.457
# ---------------- Epoch 24 ----------------
# [  0/91] Train Loss 1.813 Acc 0.375
# [ 10/91] Train Loss 1.602 Acc 0.500
# [ 20/91] Train Loss 1.372 Acc 0.562
# [ 30/91] Train Loss 1.918 Acc 0.406
# [ 40/91] Train Loss 2.080 Acc 0.375
# [ 50/91] Train Loss 2.041 Acc 0.375
# [ 60/91] Train Loss 1.705 Acc 0.469
# [ 70/91] Train Loss 1.733 Acc 0.438
# [ 80/91] Train Loss 1.823 Acc 0.500
# [ 90/91] Train Loss 2.017 Acc 0.278
# Epoch  24/75 Train Loss 1.842 Acc 0.413
# ---------------- Testing ----------------
# Epoch  24/75 Test Loss 1.753 Acc 0.442
# ---------------- Epoch 25 ----------------
# [  0/91] Train Loss 1.231 Acc 0.656
# [ 10/91] Train Loss 2.092 Acc 0.281
# [ 20/91] Train Loss 1.945 Acc 0.469
# [ 30/91] Train Loss 1.777 Acc 0.500
# [ 40/91] Train Loss 1.934 Acc 0.375
# [ 50/91] Train Loss 1.783 Acc 0.469
# [ 60/91] Train Loss 1.601 Acc 0.500
# [ 70/91] Train Loss 1.938 Acc 0.375
# [ 80/91] Train Loss 1.595 Acc 0.469
# [ 90/91] Train Loss 1.955 Acc 0.500
# Epoch  25/75 Train Loss 1.850 Acc 0.409
# ---------------- Testing ----------------
# Epoch  25/75 Test Loss 1.639 Acc 0.475
# ---------------- Epoch 26 ----------------
# [  0/91] Train Loss 2.038 Acc 0.250
# [ 10/91] Train Loss 1.750 Acc 0.375
# [ 20/91] Train Loss 2.034 Acc 0.344
# [ 30/91] Train Loss 1.734 Acc 0.500
# [ 40/91] Train Loss 1.655 Acc 0.469
# [ 50/91] Train Loss 1.556 Acc 0.375
# [ 60/91] Train Loss 1.675 Acc 0.469
# [ 70/91] Train Loss 1.441 Acc 0.594
# [ 80/91] Train Loss 2.004 Acc 0.375
# [ 90/91] Train Loss 2.102 Acc 0.333
# Epoch  26/75 Train Loss 1.822 Acc 0.412
# ---------------- Testing ----------------
# Epoch  26/75 Test Loss 1.828 Acc 0.426
# ---------------- Epoch 27 ----------------
# [  0/91] Train Loss 1.543 Acc 0.500
# [ 10/91] Train Loss 1.828 Acc 0.531
# [ 20/91] Train Loss 1.965 Acc 0.438
# [ 30/91] Train Loss 1.854 Acc 0.406
# [ 40/91] Train Loss 1.849 Acc 0.344
# [ 50/91] Train Loss 1.577 Acc 0.438
# [ 60/91] Train Loss 1.707 Acc 0.406
# [ 70/91] Train Loss 1.526 Acc 0.406
# [ 80/91] Train Loss 2.464 Acc 0.281
# [ 90/91] Train Loss 2.300 Acc 0.389
# Epoch  27/75 Train Loss 1.785 Acc 0.425
# ---------------- Testing ----------------
# Epoch  27/75 Test Loss 1.696 Acc 0.445
# ---------------- Epoch 28 ----------------
# [  0/91] Train Loss 1.655 Acc 0.469
# [ 10/91] Train Loss 1.843 Acc 0.250
# [ 20/91] Train Loss 2.054 Acc 0.406
# [ 30/91] Train Loss 1.768 Acc 0.438
# [ 40/91] Train Loss 1.858 Acc 0.531
# [ 50/91] Train Loss 1.680 Acc 0.469
# [ 60/91] Train Loss 1.754 Acc 0.438
# [ 70/91] Train Loss 1.671 Acc 0.344
# [ 80/91] Train Loss 1.748 Acc 0.406
# [ 90/91] Train Loss 1.836 Acc 0.333
# Epoch  28/75 Train Loss 1.767 Acc 0.429
# ---------------- Testing ----------------
# Epoch  28/75 Test Loss 1.626 Acc 0.493
# ---------------- Epoch 29 ----------------
# [  0/91] Train Loss 1.576 Acc 0.531
# [ 10/91] Train Loss 1.584 Acc 0.469
# [ 20/91] Train Loss 1.599 Acc 0.500
# [ 30/91] Train Loss 1.326 Acc 0.625
# [ 40/91] Train Loss 1.835 Acc 0.500
# [ 50/91] Train Loss 1.380 Acc 0.500
# [ 60/91] Train Loss 2.095 Acc 0.250
# [ 70/91] Train Loss 1.677 Acc 0.469
# [ 80/91] Train Loss 1.791 Acc 0.312
# [ 90/91] Train Loss 1.161 Acc 0.667
# Epoch  29/75 Train Loss 1.716 Acc 0.439
# ---------------- Testing ----------------
# Epoch  29/75 Test Loss 1.719 Acc 0.480
# ---------------- Epoch 30 ----------------
# [  0/91] Train Loss 1.874 Acc 0.438
# [ 10/91] Train Loss 1.741 Acc 0.406
# [ 20/91] Train Loss 1.702 Acc 0.438
# [ 30/91] Train Loss 1.763 Acc 0.469
# [ 40/91] Train Loss 1.741 Acc 0.438
# [ 50/91] Train Loss 1.640 Acc 0.469
# [ 60/91] Train Loss 1.587 Acc 0.469
# [ 70/91] Train Loss 1.385 Acc 0.594
# [ 80/91] Train Loss 1.743 Acc 0.344
# [ 90/91] Train Loss 2.123 Acc 0.278
# Epoch  30/75 Train Loss 1.726 Acc 0.449
# ---------------- Testing ----------------
# Epoch  30/75 Test Loss 1.591 Acc 0.494
# ---------------- Epoch 31 ----------------
# [  0/91] Train Loss 1.735 Acc 0.531
# [ 10/91] Train Loss 1.885 Acc 0.438
# [ 20/91] Train Loss 2.077 Acc 0.281
# [ 30/91] Train Loss 1.662 Acc 0.469
# [ 40/91] Train Loss 1.625 Acc 0.312
# [ 50/91] Train Loss 1.974 Acc 0.281
# [ 60/91] Train Loss 1.759 Acc 0.500
# [ 70/91] Train Loss 1.998 Acc 0.375
# [ 80/91] Train Loss 2.067 Acc 0.406
# [ 90/91] Train Loss 1.707 Acc 0.556
# Epoch  31/75 Train Loss 1.741 Acc 0.449
# ---------------- Testing ----------------
# Epoch  31/75 Test Loss 1.539 Acc 0.494
# ---------------- Epoch 32 ----------------
# [  0/91] Train Loss 1.345 Acc 0.562
# [ 10/91] Train Loss 1.500 Acc 0.531
# [ 20/91] Train Loss 1.506 Acc 0.594
# [ 30/91] Train Loss 1.316 Acc 0.531
# [ 40/91] Train Loss 1.801 Acc 0.406
# [ 50/91] Train Loss 2.013 Acc 0.562
# [ 60/91] Train Loss 2.082 Acc 0.312
# [ 70/91] Train Loss 1.364 Acc 0.594
# [ 80/91] Train Loss 1.638 Acc 0.594
# [ 90/91] Train Loss 1.275 Acc 0.556
# Epoch  32/75 Train Loss 1.693 Acc 0.453
# ---------------- Testing ----------------
# Epoch  32/75 Test Loss 1.931 Acc 0.404
# ---------------- Epoch 33 ----------------
# [  0/91] Train Loss 1.678 Acc 0.375
# [ 10/91] Train Loss 1.650 Acc 0.500
# [ 20/91] Train Loss 1.521 Acc 0.500
# [ 30/91] Train Loss 1.516 Acc 0.531
# [ 40/91] Train Loss 1.386 Acc 0.562
# [ 50/91] Train Loss 1.955 Acc 0.312
# [ 60/91] Train Loss 1.657 Acc 0.562
# [ 70/91] Train Loss 1.746 Acc 0.438
# [ 80/91] Train Loss 2.034 Acc 0.406
# [ 90/91] Train Loss 1.626 Acc 0.444
# Epoch  33/75 Train Loss 1.687 Acc 0.449
# ---------------- Testing ----------------
# Epoch  33/75 Test Loss 1.536 Acc 0.498
# ---------------- Epoch 34 ----------------
# [  0/91] Train Loss 1.733 Acc 0.344
# [ 10/91] Train Loss 1.905 Acc 0.344
# [ 20/91] Train Loss 1.631 Acc 0.406
# [ 30/91] Train Loss 1.476 Acc 0.562
# [ 40/91] Train Loss 1.586 Acc 0.469
# [ 50/91] Train Loss 1.783 Acc 0.500
# [ 60/91] Train Loss 1.690 Acc 0.312
# [ 70/91] Train Loss 1.477 Acc 0.531
# [ 80/91] Train Loss 1.879 Acc 0.500
# [ 90/91] Train Loss 1.874 Acc 0.500
# Epoch  34/75 Train Loss 1.672 Acc 0.460
# ---------------- Testing ----------------
# Epoch  34/75 Test Loss 2.016 Acc 0.419
# ---------------- Epoch 35 ----------------
# [  0/91] Train Loss 2.152 Acc 0.281
# [ 10/91] Train Loss 1.571 Acc 0.562
# [ 20/91] Train Loss 1.972 Acc 0.469
# [ 30/91] Train Loss 2.264 Acc 0.406
# [ 40/91] Train Loss 1.912 Acc 0.375
# [ 50/91] Train Loss 1.533 Acc 0.531
# [ 60/91] Train Loss 1.447 Acc 0.500
# [ 70/91] Train Loss 1.878 Acc 0.406
# [ 80/91] Train Loss 1.396 Acc 0.562
# [ 90/91] Train Loss 1.871 Acc 0.389
# Epoch  35/75 Train Loss 1.671 Acc 0.466
# ---------------- Testing ----------------
# Epoch  35/75 Test Loss 1.526 Acc 0.509
# ---------------- Epoch 36 ----------------
# [  0/91] Train Loss 1.271 Acc 0.531
# [ 10/91] Train Loss 1.732 Acc 0.438
# [ 20/91] Train Loss 1.622 Acc 0.469
# [ 30/91] Train Loss 2.207 Acc 0.406
# [ 40/91] Train Loss 1.742 Acc 0.438
# [ 50/91] Train Loss 1.261 Acc 0.562
# [ 60/91] Train Loss 1.509 Acc 0.500
# [ 70/91] Train Loss 1.326 Acc 0.562
# [ 80/91] Train Loss 1.782 Acc 0.406
# [ 90/91] Train Loss 1.431 Acc 0.500
# Epoch  36/75 Train Loss 1.591 Acc 0.492
# ---------------- Testing ----------------
# Epoch  36/75 Test Loss 1.526 Acc 0.517
# ---------------- Epoch 37 ----------------
# [  0/91] Train Loss 1.634 Acc 0.531
# [ 10/91] Train Loss 1.864 Acc 0.406
# [ 20/91] Train Loss 1.677 Acc 0.562
# [ 30/91] Train Loss 1.696 Acc 0.500
# [ 40/91] Train Loss 1.806 Acc 0.406
# [ 50/91] Train Loss 1.604 Acc 0.500
# [ 60/91] Train Loss 1.584 Acc 0.469
# [ 70/91] Train Loss 1.685 Acc 0.438
# [ 80/91] Train Loss 1.850 Acc 0.438
# [ 90/91] Train Loss 1.678 Acc 0.667
# Epoch  37/75 Train Loss 1.624 Acc 0.478
# ---------------- Testing ----------------
# Epoch  37/75 Test Loss 1.587 Acc 0.484
# ---------------- Epoch 38 ----------------
# [  0/91] Train Loss 1.701 Acc 0.375
# [ 10/91] Train Loss 1.788 Acc 0.438
# [ 20/91] Train Loss 1.217 Acc 0.656
# [ 30/91] Train Loss 1.841 Acc 0.406
# [ 40/91] Train Loss 1.488 Acc 0.562
# [ 50/91] Train Loss 1.683 Acc 0.406
# [ 60/91] Train Loss 1.399 Acc 0.625
# [ 70/91] Train Loss 1.602 Acc 0.500
# [ 80/91] Train Loss 1.943 Acc 0.344
# [ 90/91] Train Loss 1.763 Acc 0.333
# Epoch  38/75 Train Loss 1.603 Acc 0.470
# ---------------- Testing ----------------
# Epoch  38/75 Test Loss 1.561 Acc 0.507
# ---------------- Epoch 39 ----------------
# [  0/91] Train Loss 1.620 Acc 0.594
# [ 10/91] Train Loss 1.678 Acc 0.500
# [ 20/91] Train Loss 1.332 Acc 0.531
# [ 30/91] Train Loss 1.826 Acc 0.406
# [ 40/91] Train Loss 1.526 Acc 0.438
# [ 50/91] Train Loss 1.467 Acc 0.594
# [ 60/91] Train Loss 1.627 Acc 0.531
# [ 70/91] Train Loss 1.827 Acc 0.469
# [ 80/91] Train Loss 1.040 Acc 0.688
# [ 90/91] Train Loss 1.675 Acc 0.556
# Epoch  39/75 Train Loss 1.552 Acc 0.498
# ---------------- Testing ----------------
# Epoch  39/75 Test Loss 1.520 Acc 0.502
# ---------------- Epoch 40 ----------------
# [  0/91] Train Loss 1.399 Acc 0.531
# [ 10/91] Train Loss 1.328 Acc 0.562
# [ 20/91] Train Loss 1.523 Acc 0.531
# [ 30/91] Train Loss 0.926 Acc 0.688
# [ 40/91] Train Loss 1.329 Acc 0.562
# [ 50/91] Train Loss 1.918 Acc 0.438
# [ 60/91] Train Loss 1.805 Acc 0.406
# [ 70/91] Train Loss 1.359 Acc 0.625
# [ 80/91] Train Loss 1.046 Acc 0.688
# [ 90/91] Train Loss 1.847 Acc 0.389
# Epoch  40/75 Train Loss 1.570 Acc 0.491
# ---------------- Testing ----------------
# Epoch  40/75 Test Loss 1.655 Acc 0.495
# ---------------- Epoch 41 ----------------
# [  0/91] Train Loss 1.562 Acc 0.500
# [ 10/91] Train Loss 1.287 Acc 0.500
# [ 20/91] Train Loss 1.295 Acc 0.500
# [ 30/91] Train Loss 1.386 Acc 0.562
# [ 40/91] Train Loss 1.235 Acc 0.562
# [ 50/91] Train Loss 1.477 Acc 0.500
# [ 60/91] Train Loss 1.380 Acc 0.562
# [ 70/91] Train Loss 1.074 Acc 0.625
# [ 80/91] Train Loss 1.564 Acc 0.469
# [ 90/91] Train Loss 1.684 Acc 0.389
# Epoch  41/75 Train Loss 1.531 Acc 0.497
# ---------------- Testing ----------------
# Epoch  41/75 Test Loss 1.369 Acc 0.506
# ---------------- Epoch 42 ----------------
# [  0/91] Train Loss 1.413 Acc 0.531
# [ 10/91] Train Loss 1.867 Acc 0.375
# [ 20/91] Train Loss 1.463 Acc 0.438
# [ 30/91] Train Loss 2.045 Acc 0.406
# [ 40/91] Train Loss 1.407 Acc 0.500
# [ 50/91] Train Loss 1.532 Acc 0.469
# [ 60/91] Train Loss 1.299 Acc 0.562
# [ 70/91] Train Loss 1.382 Acc 0.500
# [ 80/91] Train Loss 1.516 Acc 0.469
# [ 90/91] Train Loss 1.218 Acc 0.667
# Epoch  42/75 Train Loss 1.522 Acc 0.491
# ---------------- Testing ----------------
# Epoch  42/75 Test Loss 1.542 Acc 0.502
# ---------------- Epoch 43 ----------------
# [  0/91] Train Loss 1.119 Acc 0.531
# [ 10/91] Train Loss 1.499 Acc 0.438
# [ 20/91] Train Loss 1.785 Acc 0.344
# [ 30/91] Train Loss 1.689 Acc 0.469
# [ 40/91] Train Loss 1.598 Acc 0.500
# [ 50/91] Train Loss 1.379 Acc 0.594
# [ 60/91] Train Loss 1.371 Acc 0.562
# [ 70/91] Train Loss 1.534 Acc 0.500
# [ 80/91] Train Loss 1.493 Acc 0.406
# [ 90/91] Train Loss 1.582 Acc 0.556
# Epoch  43/75 Train Loss 1.525 Acc 0.500
# ---------------- Testing ----------------
# Epoch  43/75 Test Loss 1.463 Acc 0.540
# ---------------- Epoch 44 ----------------
# [  0/91] Train Loss 1.699 Acc 0.562
# [ 10/91] Train Loss 1.507 Acc 0.688
# [ 20/91] Train Loss 1.445 Acc 0.594
# [ 30/91] Train Loss 1.737 Acc 0.469
# [ 40/91] Train Loss 1.380 Acc 0.562
# [ 50/91] Train Loss 1.270 Acc 0.594
# [ 60/91] Train Loss 1.702 Acc 0.438
# [ 70/91] Train Loss 1.150 Acc 0.594
# [ 80/91] Train Loss 1.669 Acc 0.375
# [ 90/91] Train Loss 1.251 Acc 0.611
# Epoch  44/75 Train Loss 1.476 Acc 0.522
# ---------------- Testing ----------------
# Epoch  44/75 Test Loss 1.488 Acc 0.528
# ---------------- Epoch 45 ----------------
# [  0/91] Train Loss 1.354 Acc 0.500
# [ 10/91] Train Loss 1.567 Acc 0.531
# [ 20/91] Train Loss 1.243 Acc 0.531
# [ 30/91] Train Loss 1.281 Acc 0.531
# [ 40/91] Train Loss 1.609 Acc 0.469
# [ 50/91] Train Loss 1.373 Acc 0.562
# [ 60/91] Train Loss 1.335 Acc 0.469
# [ 70/91] Train Loss 1.567 Acc 0.500
# [ 80/91] Train Loss 1.991 Acc 0.500
# [ 90/91] Train Loss 1.927 Acc 0.333
# Epoch  45/75 Train Loss 1.559 Acc 0.488
# ---------------- Testing ----------------
# Epoch  45/75 Test Loss 1.483 Acc 0.507
# ---------------- Epoch 46 ----------------
# [  0/91] Train Loss 1.523 Acc 0.594
# [ 10/91] Train Loss 1.528 Acc 0.500
# [ 20/91] Train Loss 1.278 Acc 0.656
# [ 30/91] Train Loss 1.254 Acc 0.656
# [ 40/91] Train Loss 1.573 Acc 0.500
# [ 50/91] Train Loss 1.553 Acc 0.625
# [ 60/91] Train Loss 1.633 Acc 0.469
# [ 70/91] Train Loss 1.463 Acc 0.500
# [ 80/91] Train Loss 1.319 Acc 0.531
# [ 90/91] Train Loss 1.645 Acc 0.389
# Epoch  46/75 Train Loss 1.446 Acc 0.527
# ---------------- Testing ----------------
# Epoch  46/75 Test Loss 1.572 Acc 0.509
# ---------------- Epoch 47 ----------------
# [  0/91] Train Loss 1.297 Acc 0.625
# [ 10/91] Train Loss 1.746 Acc 0.406
# [ 20/91] Train Loss 1.448 Acc 0.531
# [ 30/91] Train Loss 1.732 Acc 0.406
# [ 40/91] Train Loss 1.367 Acc 0.500
# [ 50/91] Train Loss 1.856 Acc 0.406
# [ 60/91] Train Loss 1.635 Acc 0.438
# [ 70/91] Train Loss 1.392 Acc 0.469
# [ 80/91] Train Loss 1.698 Acc 0.500
# [ 90/91] Train Loss 1.649 Acc 0.500
# Epoch  47/75 Train Loss 1.455 Acc 0.514
# ---------------- Testing ----------------
# Epoch  47/75 Test Loss 1.725 Acc 0.486
# ---------------- Epoch 48 ----------------
# [  0/91] Train Loss 1.317 Acc 0.625
# [ 10/91] Train Loss 0.865 Acc 0.750
# [ 20/91] Train Loss 1.113 Acc 0.656
# [ 30/91] Train Loss 1.438 Acc 0.531
# [ 40/91] Train Loss 1.343 Acc 0.594
# [ 50/91] Train Loss 1.883 Acc 0.375
# [ 60/91] Train Loss 1.410 Acc 0.469
# [ 70/91] Train Loss 1.458 Acc 0.531
# [ 80/91] Train Loss 2.056 Acc 0.438
# [ 90/91] Train Loss 1.892 Acc 0.500
# Epoch  48/75 Train Loss 1.444 Acc 0.526
# ---------------- Testing ----------------
# Epoch  48/75 Test Loss 1.431 Acc 0.521
# ---------------- Epoch 49 ----------------
# [  0/91] Train Loss 1.427 Acc 0.500
# [ 10/91] Train Loss 1.815 Acc 0.188
# [ 20/91] Train Loss 1.410 Acc 0.438
# [ 30/91] Train Loss 1.505 Acc 0.500
# [ 40/91] Train Loss 1.520 Acc 0.438
# [ 50/91] Train Loss 1.287 Acc 0.562
# [ 60/91] Train Loss 2.002 Acc 0.469
# [ 70/91] Train Loss 0.970 Acc 0.688
# [ 80/91] Train Loss 1.441 Acc 0.531
# [ 90/91] Train Loss 1.297 Acc 0.611
# Epoch  49/75 Train Loss 1.474 Acc 0.511
# ---------------- Testing ----------------
# Epoch  49/75 Test Loss 1.438 Acc 0.544
# ---------------- Epoch 50 ----------------
# [  0/91] Train Loss 1.490 Acc 0.469
# [ 10/91] Train Loss 1.303 Acc 0.562
# [ 20/91] Train Loss 1.574 Acc 0.469
# [ 30/91] Train Loss 1.355 Acc 0.500
# [ 40/91] Train Loss 1.364 Acc 0.562
# [ 50/91] Train Loss 1.798 Acc 0.312
# [ 60/91] Train Loss 1.733 Acc 0.438
# [ 70/91] Train Loss 1.347 Acc 0.562
# [ 80/91] Train Loss 1.371 Acc 0.562
# [ 90/91] Train Loss 2.153 Acc 0.500
# Epoch  50/75 Train Loss 1.397 Acc 0.539
# ---------------- Testing ----------------
# Epoch  50/75 Test Loss 1.609 Acc 0.514
# ---------------- Epoch 51 ----------------
# [  0/91] Train Loss 1.623 Acc 0.531
# [ 10/91] Train Loss 1.044 Acc 0.688
# [ 20/91] Train Loss 1.343 Acc 0.625
# [ 30/91] Train Loss 1.138 Acc 0.656
# [ 40/91] Train Loss 1.165 Acc 0.625
# [ 50/91] Train Loss 1.521 Acc 0.562
# [ 60/91] Train Loss 1.368 Acc 0.500
# [ 70/91] Train Loss 1.351 Acc 0.562
# [ 80/91] Train Loss 1.144 Acc 0.469
# [ 90/91] Train Loss 1.772 Acc 0.389
# Epoch  51/75 Train Loss 1.378 Acc 0.550
# ---------------- Testing ----------------
# Epoch  51/75 Test Loss 1.319 Acc 0.585
# ---------------- Epoch 52 ----------------
# [  0/91] Train Loss 1.288 Acc 0.562
# [ 10/91] Train Loss 1.272 Acc 0.562
# [ 20/91] Train Loss 1.293 Acc 0.469
# [ 30/91] Train Loss 1.406 Acc 0.562
# [ 40/91] Train Loss 1.598 Acc 0.438
# [ 50/91] Train Loss 1.477 Acc 0.438
# [ 60/91] Train Loss 1.637 Acc 0.438
# [ 70/91] Train Loss 1.855 Acc 0.406
# [ 80/91] Train Loss 1.305 Acc 0.625
# [ 90/91] Train Loss 1.456 Acc 0.500
# Epoch  52/75 Train Loss 1.369 Acc 0.541
# ---------------- Testing ----------------
# Epoch  52/75 Test Loss 1.274 Acc 0.571
# ---------------- Epoch 53 ----------------
# [  0/91] Train Loss 1.332 Acc 0.562
# [ 10/91] Train Loss 1.125 Acc 0.625
# [ 20/91] Train Loss 1.330 Acc 0.469
# [ 30/91] Train Loss 1.392 Acc 0.375
# [ 40/91] Train Loss 1.380 Acc 0.438
# [ 50/91] Train Loss 1.402 Acc 0.625
# [ 60/91] Train Loss 1.237 Acc 0.625
# [ 70/91] Train Loss 2.110 Acc 0.438
# [ 80/91] Train Loss 1.046 Acc 0.781
# [ 90/91] Train Loss 1.093 Acc 0.500
# Epoch  53/75 Train Loss 1.380 Acc 0.558
# ---------------- Testing ----------------
# Epoch  53/75 Test Loss 1.586 Acc 0.509
# ---------------- Epoch 54 ----------------
# [  0/91] Train Loss 1.484 Acc 0.562
# [ 10/91] Train Loss 1.381 Acc 0.500
# [ 20/91] Train Loss 1.230 Acc 0.625
# [ 30/91] Train Loss 1.312 Acc 0.500
# [ 40/91] Train Loss 1.662 Acc 0.406
# [ 50/91] Train Loss 1.508 Acc 0.438
# [ 60/91] Train Loss 1.330 Acc 0.531
# [ 70/91] Train Loss 1.200 Acc 0.562
# [ 80/91] Train Loss 1.220 Acc 0.594
# [ 90/91] Train Loss 0.855 Acc 0.667
# Epoch  54/75 Train Loss 1.406 Acc 0.528
# ---------------- Testing ----------------
# Epoch  54/75 Test Loss 1.424 Acc 0.552
# ---------------- Epoch 55 ----------------
# [  0/91] Train Loss 1.150 Acc 0.594
# [ 10/91] Train Loss 1.133 Acc 0.625
# [ 20/91] Train Loss 1.381 Acc 0.531
# [ 30/91] Train Loss 1.451 Acc 0.562
# [ 40/91] Train Loss 1.410 Acc 0.594
# [ 50/91] Train Loss 0.990 Acc 0.594
# [ 60/91] Train Loss 1.189 Acc 0.625
# [ 70/91] Train Loss 1.646 Acc 0.438
# [ 80/91] Train Loss 0.952 Acc 0.688
# [ 90/91] Train Loss 1.462 Acc 0.667
# Epoch  55/75 Train Loss 1.339 Acc 0.561
# ---------------- Testing ----------------
# Epoch  55/75 Test Loss 1.444 Acc 0.546
# ---------------- Epoch 56 ----------------
# [  0/91] Train Loss 1.600 Acc 0.531
# [ 10/91] Train Loss 1.585 Acc 0.469
# [ 20/91] Train Loss 1.465 Acc 0.438
# [ 30/91] Train Loss 1.365 Acc 0.500
# [ 40/91] Train Loss 1.087 Acc 0.656
# [ 50/91] Train Loss 0.903 Acc 0.656
# [ 60/91] Train Loss 1.011 Acc 0.594
# [ 70/91] Train Loss 1.426 Acc 0.625
# [ 80/91] Train Loss 1.284 Acc 0.531
# [ 90/91] Train Loss 1.324 Acc 0.611
# Epoch  56/75 Train Loss 1.353 Acc 0.556
# ---------------- Testing ----------------
# Epoch  56/75 Test Loss 1.204 Acc 0.618
# ---------------- Epoch 57 ----------------
# [  0/91] Train Loss 1.112 Acc 0.625
# [ 10/91] Train Loss 1.352 Acc 0.469
# [ 20/91] Train Loss 1.811 Acc 0.438
# [ 30/91] Train Loss 1.338 Acc 0.625
# [ 40/91] Train Loss 1.680 Acc 0.438
# [ 50/91] Train Loss 1.619 Acc 0.438
# [ 60/91] Train Loss 1.494 Acc 0.562
# [ 70/91] Train Loss 1.597 Acc 0.469
# [ 80/91] Train Loss 1.718 Acc 0.500
# [ 90/91] Train Loss 1.408 Acc 0.500
# Epoch  57/75 Train Loss 1.333 Acc 0.563
# ---------------- Testing ----------------
# Epoch  57/75 Test Loss 1.236 Acc 0.605
# ---------------- Epoch 58 ----------------
# [  0/91] Train Loss 1.345 Acc 0.594
# [ 10/91] Train Loss 1.291 Acc 0.594
# [ 20/91] Train Loss 1.159 Acc 0.594
# [ 30/91] Train Loss 1.583 Acc 0.500
# [ 40/91] Train Loss 1.419 Acc 0.500
# [ 50/91] Train Loss 1.201 Acc 0.594
# [ 60/91] Train Loss 1.476 Acc 0.562
# [ 70/91] Train Loss 1.173 Acc 0.594
# [ 80/91] Train Loss 1.560 Acc 0.469
# [ 90/91] Train Loss 1.149 Acc 0.556
# Epoch  58/75 Train Loss 1.326 Acc 0.562
# ---------------- Testing ----------------
# Epoch  58/75 Test Loss 1.283 Acc 0.566
# ---------------- Epoch 59 ----------------
# [  0/91] Train Loss 1.346 Acc 0.500
# [ 10/91] Train Loss 1.436 Acc 0.500
# [ 20/91] Train Loss 1.572 Acc 0.500
# [ 30/91] Train Loss 1.493 Acc 0.562
# [ 40/91] Train Loss 1.365 Acc 0.469
# [ 50/91] Train Loss 1.298 Acc 0.625
# [ 60/91] Train Loss 1.166 Acc 0.625
# [ 70/91] Train Loss 1.141 Acc 0.594
# [ 80/91] Train Loss 1.255 Acc 0.594
# [ 90/91] Train Loss 1.307 Acc 0.500
# Epoch  59/75 Train Loss 1.299 Acc 0.578
# ---------------- Testing ----------------
# Epoch  59/75 Test Loss 1.264 Acc 0.573
# ---------------- Epoch 60 ----------------
# [  0/91] Train Loss 1.056 Acc 0.625
# [ 10/91] Train Loss 1.731 Acc 0.594
# [ 20/91] Train Loss 1.299 Acc 0.531
# [ 30/91] Train Loss 1.632 Acc 0.469
# [ 40/91] Train Loss 1.250 Acc 0.500
# [ 50/91] Train Loss 0.953 Acc 0.625
# [ 60/91] Train Loss 1.350 Acc 0.562
# [ 70/91] Train Loss 1.193 Acc 0.594
# [ 80/91] Train Loss 1.239 Acc 0.531
# [ 90/91] Train Loss 1.337 Acc 0.667
# Epoch  60/75 Train Loss 1.331 Acc 0.571
# ---------------- Testing ----------------
# Epoch  60/75 Test Loss 1.635 Acc 0.513
# ---------------- Epoch 61 ----------------
# [  0/91] Train Loss 1.684 Acc 0.406
# [ 10/91] Train Loss 1.301 Acc 0.594
# [ 20/91] Train Loss 1.258 Acc 0.469
# [ 30/91] Train Loss 0.869 Acc 0.625
# [ 40/91] Train Loss 1.813 Acc 0.531
# [ 50/91] Train Loss 1.673 Acc 0.438
# [ 60/91] Train Loss 0.879 Acc 0.719
# [ 70/91] Train Loss 0.901 Acc 0.781
# [ 80/91] Train Loss 1.047 Acc 0.719
# [ 90/91] Train Loss 1.027 Acc 0.611
# Epoch  61/75 Train Loss 1.313 Acc 0.564
# ---------------- Testing ----------------
# Epoch  61/75 Test Loss 1.226 Acc 0.603
# ---------------- Epoch 62 ----------------
# [  0/91] Train Loss 0.964 Acc 0.625
# [ 10/91] Train Loss 1.344 Acc 0.594
# [ 20/91] Train Loss 1.302 Acc 0.531
# [ 30/91] Train Loss 1.053 Acc 0.719
# [ 40/91] Train Loss 1.114 Acc 0.656
# [ 50/91] Train Loss 0.990 Acc 0.688
# [ 60/91] Train Loss 1.331 Acc 0.562
# [ 70/91] Train Loss 1.509 Acc 0.562
# [ 80/91] Train Loss 1.053 Acc 0.562
# [ 90/91] Train Loss 1.577 Acc 0.611
# Epoch  62/75 Train Loss 1.318 Acc 0.575
# ---------------- Testing ----------------
# Epoch  62/75 Test Loss 1.294 Acc 0.573
# ---------------- Epoch 63 ----------------
# [  0/91] Train Loss 0.856 Acc 0.656
# [ 10/91] Train Loss 0.989 Acc 0.656
# [ 20/91] Train Loss 1.078 Acc 0.594
# [ 30/91] Train Loss 1.409 Acc 0.406
# [ 40/91] Train Loss 1.079 Acc 0.594
# [ 50/91] Train Loss 1.088 Acc 0.656
# [ 60/91] Train Loss 1.307 Acc 0.594
# [ 70/91] Train Loss 0.993 Acc 0.625
# [ 80/91] Train Loss 1.302 Acc 0.594
# [ 90/91] Train Loss 1.686 Acc 0.333
# Epoch  63/75 Train Loss 1.271 Acc 0.580
# ---------------- Testing ----------------
# Epoch  63/75 Test Loss 1.281 Acc 0.582
# ---------------- Epoch 64 ----------------
# [  0/91] Train Loss 0.844 Acc 0.781
# [ 10/91] Train Loss 1.600 Acc 0.438
# [ 20/91] Train Loss 1.191 Acc 0.562
# [ 30/91] Train Loss 1.440 Acc 0.500
# [ 40/91] Train Loss 1.448 Acc 0.531
# [ 50/91] Train Loss 1.596 Acc 0.469
# [ 60/91] Train Loss 1.146 Acc 0.562
# [ 70/91] Train Loss 1.173 Acc 0.688
# [ 80/91] Train Loss 1.182 Acc 0.594
# [ 90/91] Train Loss 0.776 Acc 0.667
# Epoch  64/75 Train Loss 1.236 Acc 0.593
# ---------------- Testing ----------------
# Epoch  64/75 Test Loss 1.379 Acc 0.586
# ---------------- Epoch 65 ----------------
# [  0/91] Train Loss 1.095 Acc 0.625
# [ 10/91] Train Loss 1.285 Acc 0.531
# [ 20/91] Train Loss 1.309 Acc 0.500
# [ 30/91] Train Loss 0.985 Acc 0.750
# [ 40/91] Train Loss 1.367 Acc 0.625
# [ 50/91] Train Loss 1.404 Acc 0.594
# [ 60/91] Train Loss 1.300 Acc 0.531
# [ 70/91] Train Loss 1.333 Acc 0.625
# [ 80/91] Train Loss 1.642 Acc 0.562
# [ 90/91] Train Loss 1.019 Acc 0.722
# Epoch  65/75 Train Loss 1.272 Acc 0.589
# ---------------- Testing ----------------
# Epoch  65/75 Test Loss 1.339 Acc 0.578
# ---------------- Epoch 66 ----------------
# [  0/91] Train Loss 0.833 Acc 0.750
# [ 10/91] Train Loss 1.052 Acc 0.656
# [ 20/91] Train Loss 1.460 Acc 0.469
# [ 30/91] Train Loss 0.829 Acc 0.719
# [ 40/91] Train Loss 1.043 Acc 0.625
# [ 50/91] Train Loss 1.051 Acc 0.688
# [ 60/91] Train Loss 1.685 Acc 0.469
# [ 70/91] Train Loss 1.369 Acc 0.562
# [ 80/91] Train Loss 1.287 Acc 0.625
# [ 90/91] Train Loss 1.549 Acc 0.556
# Epoch  66/75 Train Loss 1.233 Acc 0.603
# ---------------- Testing ----------------
# Epoch  66/75 Test Loss 1.284 Acc 0.569
# ---------------- Epoch 67 ----------------
# [  0/91] Train Loss 1.222 Acc 0.719
# [ 10/91] Train Loss 0.856 Acc 0.656
# [ 20/91] Train Loss 0.847 Acc 0.750
# [ 30/91] Train Loss 1.167 Acc 0.625
# [ 40/91] Train Loss 1.112 Acc 0.594
# [ 50/91] Train Loss 1.110 Acc 0.469
# [ 60/91] Train Loss 1.672 Acc 0.594
# [ 70/91] Train Loss 0.848 Acc 0.688
# [ 80/91] Train Loss 1.591 Acc 0.594
# [ 90/91] Train Loss 1.104 Acc 0.722
# Epoch  67/75 Train Loss 1.229 Acc 0.586
# ---------------- Testing ----------------
# Epoch  67/75 Test Loss 1.404 Acc 0.567
# ---------------- Epoch 68 ----------------
# [  0/91] Train Loss 1.212 Acc 0.625
# [ 10/91] Train Loss 1.195 Acc 0.531
# [ 20/91] Train Loss 1.230 Acc 0.531
# [ 30/91] Train Loss 1.175 Acc 0.594
# [ 40/91] Train Loss 1.349 Acc 0.531
# [ 50/91] Train Loss 1.479 Acc 0.594
# [ 60/91] Train Loss 1.098 Acc 0.688
# [ 70/91] Train Loss 1.084 Acc 0.656
# [ 80/91] Train Loss 1.265 Acc 0.531
# [ 90/91] Train Loss 1.271 Acc 0.556
# Epoch  68/75 Train Loss 1.210 Acc 0.602
# ---------------- Testing ----------------
# Epoch  68/75 Test Loss 1.724 Acc 0.521
# ---------------- Epoch 69 ----------------
# [  0/91] Train Loss 1.158 Acc 0.656
# [ 10/91] Train Loss 1.163 Acc 0.531
# [ 20/91] Train Loss 1.192 Acc 0.656
# [ 30/91] Train Loss 1.402 Acc 0.625
# [ 40/91] Train Loss 1.258 Acc 0.562
# [ 50/91] Train Loss 1.559 Acc 0.406
# [ 60/91] Train Loss 1.369 Acc 0.500
# [ 70/91] Train Loss 1.116 Acc 0.625
# [ 80/91] Train Loss 1.470 Acc 0.438
# [ 90/91] Train Loss 1.340 Acc 0.500
# Epoch  69/75 Train Loss 1.231 Acc 0.594
# ---------------- Testing ----------------
# Epoch  69/75 Test Loss 1.382 Acc 0.586
# ---------------- Epoch 70 ----------------
# [  0/91] Train Loss 0.934 Acc 0.656
# [ 10/91] Train Loss 0.679 Acc 0.844
# [ 20/91] Train Loss 1.212 Acc 0.625
# [ 30/91] Train Loss 1.091 Acc 0.688
# [ 40/91] Train Loss 0.905 Acc 0.656
# [ 50/91] Train Loss 1.507 Acc 0.500
# [ 60/91] Train Loss 1.172 Acc 0.656
# [ 70/91] Train Loss 1.011 Acc 0.656
# [ 80/91] Train Loss 1.216 Acc 0.594
# [ 90/91] Train Loss 1.627 Acc 0.556
# Epoch  70/75 Train Loss 1.204 Acc 0.599
# ---------------- Testing ----------------
# Epoch  70/75 Test Loss 1.219 Acc 0.597
# ---------------- Epoch 71 ----------------
# [  0/91] Train Loss 1.318 Acc 0.531
# [ 10/91] Train Loss 1.119 Acc 0.750
# [ 20/91] Train Loss 1.191 Acc 0.625
# [ 30/91] Train Loss 0.880 Acc 0.781
# [ 40/91] Train Loss 1.438 Acc 0.406
# [ 50/91] Train Loss 1.295 Acc 0.594
# [ 60/91] Train Loss 0.960 Acc 0.625
# [ 70/91] Train Loss 1.409 Acc 0.625
# [ 80/91] Train Loss 1.307 Acc 0.500
# [ 90/91] Train Loss 1.251 Acc 0.556
# Epoch  71/75 Train Loss 1.205 Acc 0.601
# ---------------- Testing ----------------
# Epoch  71/75 Test Loss 1.357 Acc 0.576
# ---------------- Epoch 72 ----------------
# [  0/91] Train Loss 1.275 Acc 0.562
# [ 10/91] Train Loss 1.023 Acc 0.688
# [ 20/91] Train Loss 1.007 Acc 0.656
# [ 30/91] Train Loss 0.868 Acc 0.656
# [ 40/91] Train Loss 1.491 Acc 0.562
# [ 50/91] Train Loss 0.642 Acc 0.812
# [ 60/91] Train Loss 1.104 Acc 0.719
# [ 70/91] Train Loss 1.363 Acc 0.469
# [ 80/91] Train Loss 0.886 Acc 0.656
# [ 90/91] Train Loss 1.132 Acc 0.722
# Epoch  72/75 Train Loss 1.164 Acc 0.622
# ---------------- Testing ----------------
# Epoch  72/75 Test Loss 1.145 Acc 0.638
# ---------------- Epoch 73 ----------------
# [  0/91] Train Loss 1.281 Acc 0.594
# [ 10/91] Train Loss 1.381 Acc 0.625
# [ 20/91] Train Loss 1.493 Acc 0.531
# [ 30/91] Train Loss 1.064 Acc 0.656
# [ 40/91] Train Loss 1.345 Acc 0.594
# [ 50/91] Train Loss 0.924 Acc 0.750
# [ 60/91] Train Loss 1.101 Acc 0.750
# [ 70/91] Train Loss 1.158 Acc 0.594
# [ 80/91] Train Loss 0.838 Acc 0.719
# [ 90/91] Train Loss 1.212 Acc 0.611
# Epoch  73/75 Train Loss 1.178 Acc 0.620
# ---------------- Testing ----------------
# Epoch  73/75 Test Loss 1.325 Acc 0.585
# ---------------- Epoch 74 ----------------
# [  0/91] Train Loss 0.957 Acc 0.625
# [ 10/91] Train Loss 1.189 Acc 0.594
# [ 20/91] Train Loss 1.653 Acc 0.531
# [ 30/91] Train Loss 1.236 Acc 0.688
# [ 40/91] Train Loss 1.011 Acc 0.656
# [ 50/91] Train Loss 1.031 Acc 0.625
# [ 60/91] Train Loss 1.044 Acc 0.656
# [ 70/91] Train Loss 0.934 Acc 0.750
# [ 80/91] Train Loss 0.707 Acc 0.750
# [ 90/91] Train Loss 1.432 Acc 0.500
# Epoch  74/75 Train Loss 1.202 Acc 0.609
# ---------------- Testing ----------------
# Epoch  74/75 Test Loss 1.246 Acc 0.619
# ---------------- Epoch 75 ----------------
# [  0/91] Train Loss 1.008 Acc 0.594
# [ 10/91] Train Loss 0.958 Acc 0.750
# [ 20/91] Train Loss 0.903 Acc 0.750
# [ 30/91] Train Loss 1.252 Acc 0.562
# [ 40/91] Train Loss 0.763 Acc 0.750
# [ 50/91] Train Loss 1.074 Acc 0.594
# [ 60/91] Train Loss 1.020 Acc 0.656
# [ 70/91] Train Loss 1.335 Acc 0.594
# [ 80/91] Train Loss 1.205 Acc 0.625
# [ 90/91] Train Loss 1.122 Acc 0.611
# Epoch  75/75 Train Loss 1.122 Acc 0.633
# ---------------- Testing ----------------
# Epoch  75/75 Test Loss 1.257 Acc 0.623
# --------------------
# The Best accuracy is 0.638 at epoch 72

# %% [markdown]
# ### 3.3 儲存模型
# PyTorch 提供 ```torch.save()``` API 可以儲存模型。
#
# PyTorch 建議使用 ```state_dict``` 來儲存模型(要存整個模型也可以)，```state_dict``` 包含模型的可學習參數(如 conv layers 的 weight 和 bias) 以及 registered buffer (如 batchnorm running mean) 。 由於 ```state_dict``` 屬於 python dictionaries ，所以有很大的使用彈性。
#
# 這裡我們只儲存最後的模型狀態，你也可以在每一個 epoch 後儲存一個節點或儲存擁有最佳表現的模型。常用的附檔名為 ```.pt``` 或 ```.pth```。
#
# 請完成以下 ? 處。

# %%
save_path = 'mymodel.pth'
torch.save(model.state_dict(), save_path)

# %% [markdown]
# ### 3.4 繪製訓練過程的 loss 與 accuracy 變化
# 在訓練過程中，我們透過 ```list``` 儲存每個 epoch 的 loss 和 accuracy，現在透過 ```matplotlib.pyplot``` 將這些數值畫成圖表，可以幫助我們分析訓練過程的變化。
#
# 請完成以下 ? 處

# %%
# plotting loss curves
x = list(range(EPOCHS))
plt.plot(x, train_loss, x, test_loss)
plt.title('Training & Testing Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training', 'Testing'])
plt.show()

# %%
# plotting acc curves
x = list(range(EPOCHS))
plt.plot(x, train_acc, x, test_acc)
plt.title('Training & Testing Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training', 'Testing'])
plt.show()

# %% [markdown]
# ## 參考資料 & 教學
#
# ### Transformations
# + https://pytorch.org/tutorials/beginner/basics/transforms_tutorial.html
# + https://pytorch.org/vision/stable/transforms.html 可以知道每種方法產生的效果
# + https://chih-sheng-huang821.medium.com/03-pytorch-dataaug-a712a7a7f55e
#
# ### Dataset
# + https://pytorch.org/tutorials/beginner/data_loading_tutorial.html#dataset-class
# + https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#creating-a-custom-dataset-for-your-files
#
# ### Dataloader
# + https://pytorch.org/tutorials/beginner/basics/data_tutorial.html#preparing-your-data-for-training-with-dataloaders
#
# ### Model
# #### Module
# + https://pytorch.org/docs/stable/generated/torch.nn.Module.html
# + https://pytorch.org/docs/stable/nn.html (conv, batchnorm, pooling layer 的詳細用法可以在這裡找到)
#
# #### Custom Model
# + https://pytorch.org/tutorials/beginner/examples_nn/two_layer_net_module.html
#
# #### nn.Sequential
# + https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html
#
# ### Training
# #### Optimizer
# + https://pytorch.org/docs/stable/optim.html
#
# #### Loss function
# + https://pytorch.org/docs/stable/nn.html#loss-functions
#
#
# #### Saving model
# + https://pytorch.org/tutorials/beginner/saving_loading_models.html
